# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %%
# OpenWeatherMap API Key
api_key = "ec81b973b4b92a260f455e88cc103bef"

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=burnie
# Processing Record 2 of Set 1 | tucuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tucuma
# City not found. Skipping...
# Processing Record 3 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mataura
# Processing Record 4 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ribeira%20grande
# Processing Record 5 of Set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=fortuna
# Processing Record 6 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vaini
# Processing Record 7 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ponta%20do%20sol
# Processing Record 8 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=albany
# Processing Record 9 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saint-philippe
# Processing Record 10 of Set 1 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=upernavik
# Processing Record 11 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bredasdorp
# Processing Record 12 of Set 1 | zhanatas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=zhanatas
# City not found. Skipping...
# Processing Record 13 of Set 1 | chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=chara
# Processing Record 14 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=butaritari
# Processing Record 15 of Set 1 | nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nizwa
# Processing Record 16 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=barrow
# Processing Record 17 of Set 1 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=rikitea
# Processing Record 19 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hilo
# Processing Record 20 of Set 1 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=harper
# Processing Record 21 of Set 1 | borama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=borama
# City not found. Skipping...
# Processing Record 22 of Set 1 | coihueco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=coihueco
# Processing Record 23 of Set 1 | mersing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mersing
# Processing Record 24 of Set 1 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=itarema
# Processing Record 25 of Set 1 | belchertown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=belchertown
# Processing Record 26 of Set 1 | inta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=inta
# Processing Record 27 of Set 1 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=banda%20aceh
# Processing Record 28 of Set 1 | hailey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hailey
# Processing Record 29 of Set 1 | paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=paita
# Processing Record 30 of Set 1 | vesyegonsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vesyegonsk
# Processing Record 31 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=klaksvik
# Processing Record 32 of Set 1 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cabedelo
# Processing Record 33 of Set 1 | burgeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=burgeo
# Processing Record 34 of Set 1 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=aykhal
# Processing Record 35 of Set 1 | katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=katherine
# Processing Record 36 of Set 1 | marv dasht
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=marv%20dasht
# City not found. Skipping...
# Processing Record 37 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bethel
# Processing Record 38 of Set 1 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hamilton
# Processing Record 39 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ushuaia
# Processing Record 40 of Set 1 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lazaro%20cardenas
# Processing Record 41 of Set 1 | challapata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=challapata
# Processing Record 42 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bluff
# Processing Record 43 of Set 1 | nioro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nioro
# Processing Record 44 of Set 1 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nanortalik
# Processing Record 45 of Set 1 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bandarbeyla
# Processing Record 46 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tuktoyaktuk
# Processing Record 47 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=port%20alfred
# Processing Record 48 of Set 1 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=pevek
# Processing Record 49 of Set 1 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=aklavik
# Processing Record 50 of Set 1 | manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=manta
# Processing Record 0 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yellowknife
# Processing Record 1 of Set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=puerto%20ayora
# Processing Record 2 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saint%20george
# Processing Record 3 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cape%20town
# Processing Record 4 of Set 2 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bilma
# Processing Record 5 of Set 2 | markova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=markova
# Processing Record 6 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=dikson
# Processing Record 7 of Set 2 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hervey%20bay
# Processing Record 8 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=atuona
# Processing Record 9 of Set 2 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vila%20franca%20do%20campo
# Processing Record 10 of Set 2 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=toliary
# City not found. Skipping...
# Processing Record 11 of Set 2 | corinto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=corinto
# Processing Record 12 of Set 2 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=leningradskiy
# Processing Record 13 of Set 2 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=henties%20bay
# Processing Record 14 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hobart
# Processing Record 15 of Set 2 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lavrentiya
# Processing Record 16 of Set 2 | temaraia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=temaraia
# City not found. Skipping...
# Processing Record 17 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lebu
# Processing Record 18 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=east%20london
# Processing Record 19 of Set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=victoria
# Processing Record 21 of Set 2 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=port%20hardy
# Processing Record 22 of Set 2 | panjakent
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=panjakent
# Processing Record 23 of Set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kapaa
# Processing Record 25 of Set 2 | verkhniy tagil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=verkhniy%20tagil
# Processing Record 26 of Set 2 | maulvi bazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=maulvi%20bazar
# City not found. Skipping...
# Processing Record 27 of Set 2 | pandan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=pandan
# Processing Record 28 of Set 2 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bargal
# City not found. Skipping...
# Processing Record 29 of Set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=luderitz
# Processing Record 30 of Set 2 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bathsheba
# Processing Record 31 of Set 2 | burley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=burley
# Processing Record 32 of Set 2 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=labuhan
# Processing Record 33 of Set 2 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=puerto%20escondido
# Processing Record 34 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=punta%20arenas
# Processing Record 35 of Set 2 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=haines%20junction
# Processing Record 36 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=busselton
# Processing Record 37 of Set 2 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 2 | jetpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=jetpur
# Processing Record 39 of Set 2 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=carnarvon
# Processing Record 40 of Set 2 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lagoa
# Processing Record 41 of Set 2 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ilulissat
# Processing Record 42 of Set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=georgetown
# Processing Record 43 of Set 2 | ngunguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ngunguru
# Processing Record 44 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hermanus
# Processing Record 45 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mar%20del%20plata
# Processing Record 46 of Set 2 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kaitangata
# Processing Record 47 of Set 2 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tiksi
# Processing Record 48 of Set 2 | carballo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=carballo
# Processing Record 49 of Set 2 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yulara
# Processing Record 0 of Set 3 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tuatapere
# Processing Record 1 of Set 3 | benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=benguela
# Processing Record 2 of Set 3 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vila%20velha
# Processing Record 3 of Set 3 | plainview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=plainview
# Processing Record 4 of Set 3 | freeport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=freeport
# Processing Record 5 of Set 3 | mrirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mrirt
# City not found. Skipping...
# Processing Record 6 of Set 3 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kahului
# Processing Record 7 of Set 3 | zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=zhezkazgan
# Processing Record 8 of Set 3 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=flinders
# Processing Record 9 of Set 3 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=arraial%20do%20cabo
# Processing Record 10 of Set 3 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=thompson
# Processing Record 11 of Set 3 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=coquimbo
# Processing Record 12 of Set 3 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=fort%20nelson
# Processing Record 13 of Set 3 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=san%20patricio
# Processing Record 14 of Set 3 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tasiilaq
# Processing Record 15 of Set 3 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=jamestown
# Processing Record 16 of Set 3 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=iqaluit
# Processing Record 17 of Set 3 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=marsh%20harbour
# Processing Record 18 of Set 3 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=port%20lincoln
# Processing Record 19 of Set 3 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=avarua
# Processing Record 20 of Set 3 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=geraldton
# Processing Record 21 of Set 3 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=belmonte
# Processing Record 22 of Set 3 | maxixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=maxixe
# Processing Record 23 of Set 3 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=chicama
# Processing Record 24 of Set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=longyearbyen
# Processing Record 25 of Set 3 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=constitucion
# Processing Record 26 of Set 3 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=porto%20novo
# Processing Record 27 of Set 3 | san julian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=san%20julian
# Processing Record 28 of Set 3 | manzil salim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=manzil%20salim
# Processing Record 29 of Set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mahebourg
# Processing Record 30 of Set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bambous%20virieux
# Processing Record 31 of Set 3 | san luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=san%20luis
# Processing Record 32 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=chokurdakh
# Processing Record 33 of Set 3 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saint-pierre
# Processing Record 34 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=castro
# Processing Record 35 of Set 3 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=katsuura
# Processing Record 36 of Set 3 | balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=balkhash
# Processing Record 37 of Set 3 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=gat
# Processing Record 38 of Set 3 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=belushya%20guba
# City not found. Skipping...
# Processing Record 39 of Set 3 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 3 | west wendover
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=west%20wendover
# Processing Record 41 of Set 3 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 3 | dingtao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=dingtao
# Processing Record 43 of Set 3 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=waingapu
# Processing Record 44 of Set 3 | kijang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kijang
# Processing Record 45 of Set 3 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lompoc
# Processing Record 46 of Set 3 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kruisfontein
# Processing Record 47 of Set 3 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tilichiki
# Processing Record 48 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=port%20elizabeth
# Processing Record 49 of Set 3 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=torbay
# Processing Record 0 of Set 4 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saint-georges
# Processing Record 1 of Set 4 | aktau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=aktau
# Processing Record 2 of Set 4 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=taoudenni
# Processing Record 3 of Set 4 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=margate
# Processing Record 4 of Set 4 | puerto leguizamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=puerto%20leguizamo
# Processing Record 5 of Set 4 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=pangody
# Processing Record 6 of Set 4 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mayo
# Processing Record 7 of Set 4 | la brea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=la%20brea
# Processing Record 8 of Set 4 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 4 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lorengau
# Processing Record 10 of Set 4 | novaya malykla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=novaya%20malykla
# Processing Record 11 of Set 4 | pudozh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=pudozh
# Processing Record 12 of Set 4 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=codrington
# Processing Record 13 of Set 4 | zhicheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=zhicheng
# Processing Record 14 of Set 4 | warrnambool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=warrnambool
# Processing Record 15 of Set 4 | jibuti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=jibuti
# City not found. Skipping...
# Processing Record 16 of Set 4 | uralskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=uralskiy
# City not found. Skipping...
# Processing Record 17 of Set 4 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nikolskoye
# Processing Record 18 of Set 4 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yumen
# Processing Record 19 of Set 4 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hofn
# Processing Record 20 of Set 4 | haimen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=haimen
# Processing Record 21 of Set 4 | dubbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=dubbo
# Processing Record 22 of Set 4 | yongan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yongan
# Processing Record 23 of Set 4 | shalazhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=shalazhi
# Processing Record 24 of Set 4 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=rio%20gallegos
# Processing Record 25 of Set 4 | montepuez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=montepuez
# Processing Record 26 of Set 4 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=padang
# Processing Record 27 of Set 4 | san ramon de la nueva oran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=san%20ramon%20de%20la%20nueva%20oran
# Processing Record 28 of Set 4 | chinchani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=chinchani
# Processing Record 29 of Set 4 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=chagda
# City not found. Skipping...
# Processing Record 30 of Set 4 | phalaborwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=phalaborwa
# Processing Record 31 of Set 4 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=guerrero%20negro
# Processing Record 32 of Set 4 | areia branca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=areia%20branca
# Processing Record 33 of Set 4 | george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=george
# Processing Record 34 of Set 4 | halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=halifax
# Processing Record 35 of Set 4 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=baruun-urt
# Processing Record 36 of Set 4 | masumbwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=masumbwe
# Processing Record 37 of Set 4 | smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=smithers
# Processing Record 38 of Set 4 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=antofagasta
# Processing Record 39 of Set 4 | wakkanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=wakkanai
# Processing Record 40 of Set 4 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saleaula
# City not found. Skipping...
# Processing Record 41 of Set 4 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hithadhoo
# Processing Record 42 of Set 4 | nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nouakchott
# Processing Record 43 of Set 4 | umba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=umba
# Processing Record 44 of Set 4 | sydney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sydney
# Processing Record 45 of Set 4 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=camacha
# Processing Record 46 of Set 4 | jimma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=jimma
# Processing Record 47 of Set 4 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sambava
# Processing Record 48 of Set 4 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=caravelas
# Processing Record 49 of Set 4 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=pisco
# Processing Record 0 of Set 5 | minab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=minab
# Processing Record 1 of Set 5 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=te%20anau
# Processing Record 2 of Set 5 | lishui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lishui
# Processing Record 3 of Set 5 | bida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bida
# Processing Record 4 of Set 5 | sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sangar
# Processing Record 5 of Set 5 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=plettenberg%20bay
# Processing Record 6 of Set 5 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ketchikan
# Processing Record 7 of Set 5 | griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=griffith
# Processing Record 8 of Set 5 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=alofi
# Processing Record 9 of Set 5 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=severo-kurilsk
# Processing Record 10 of Set 5 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=los%20llanos%20de%20aridane
# Processing Record 11 of Set 5 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=halalo
# City not found. Skipping...
# Processing Record 12 of Set 5 | matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=matara
# Processing Record 13 of Set 5 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=talnakh
# Processing Record 14 of Set 5 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=new%20norfolk
# Processing Record 15 of Set 5 | barinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=barinas
# Processing Record 16 of Set 5 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=saldanha
# Processing Record 17 of Set 5 | sredniy ikorets
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sredniy%20ikorets
# Processing Record 18 of Set 5 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ostrovnoy
# Processing Record 19 of Set 5 | lingyuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lingyuan
# Processing Record 20 of Set 5 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sibolga
# Processing Record 21 of Set 5 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=maniitsoq
# Processing Record 22 of Set 5 | great falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=great%20falls
# Processing Record 23 of Set 5 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kulhudhuffushi
# Processing Record 24 of Set 5 | akyab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=akyab
# City not found. Skipping...
# Processing Record 25 of Set 5 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vostok
# Processing Record 26 of Set 5 | solovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 5 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sabang
# Processing Record 28 of Set 5 | barra patuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=barra%20patuca
# Processing Record 29 of Set 5 | mehran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mehran
# Processing Record 30 of Set 5 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tessalit
# Processing Record 31 of Set 5 | dekoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=dekoa
# City not found. Skipping...
# Processing Record 32 of Set 5 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=dicabisagan
# Processing Record 33 of Set 5 | amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=amapa
# Processing Record 34 of Set 5 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=itoman
# Processing Record 35 of Set 5 | ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ternate
# Processing Record 36 of Set 5 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=olafsvik
# City not found. Skipping...
# Processing Record 37 of Set 5 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=araouane
# Processing Record 38 of Set 5 | zhanakorgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=zhanakorgan
# Processing Record 39 of Set 5 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=russell
# Processing Record 40 of Set 5 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cherskiy
# Processing Record 41 of Set 5 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mys%20shmidta
# City not found. Skipping...
# Processing Record 42 of Set 5 | hammonton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hammonton
# Processing Record 43 of Set 5 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=pangnirtung
# Processing Record 44 of Set 5 | olkhovatka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=olkhovatka
# Processing Record 45 of Set 5 | surazh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=surazh
# Processing Record 46 of Set 5 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kodiak
# Processing Record 47 of Set 5 | reconquista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=reconquista
# Processing Record 48 of Set 5 | tomohon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tomohon
# Processing Record 49 of Set 5 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cabo%20san%20lucas
# Processing Record 0 of Set 6 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=manokwari
# Processing Record 1 of Set 6 | cravo norte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cravo%20norte
# Processing Record 2 of Set 6 | kismayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kismayo
# City not found. Skipping...
# Processing Record 3 of Set 6 | coachella
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=coachella
# Processing Record 4 of Set 6 | portpatrick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=portpatrick
# City not found. Skipping...
# Processing Record 5 of Set 6 | ocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ocos
# Processing Record 6 of Set 6 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sitka
# Processing Record 7 of Set 6 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ancud
# Processing Record 8 of Set 6 | keshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=keshan
# City not found. Skipping...
# Processing Record 9 of Set 6 | wulanhaote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=wulanhaote
# City not found. Skipping...
# Processing Record 10 of Set 6 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hasaki
# Processing Record 11 of Set 6 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kavaratti
# Processing Record 12 of Set 6 | zermatt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=zermatt
# Processing Record 13 of Set 6 | mikkeli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mikkeli
# Processing Record 14 of Set 6 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=grand%20river%20south%20east
# City not found. Skipping...
# Processing Record 15 of Set 6 | grand-santi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=grand-santi
# Processing Record 16 of Set 6 | tsiroanomandidy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tsiroanomandidy
# Processing Record 17 of Set 6 | lulea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lulea
# Processing Record 18 of Set 6 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 6 | marondera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=marondera
# Processing Record 20 of Set 6 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=souillac
# Processing Record 21 of Set 6 | kadykchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 6 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=chuy
# Processing Record 23 of Set 6 | mezhova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mezhova
# Processing Record 24 of Set 6 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=provideniya
# Processing Record 25 of Set 6 | boditi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=boditi
# Processing Record 26 of Set 6 | fayaoue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=fayaoue
# Processing Record 27 of Set 6 | dalbandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=dalbandin
# Processing Record 28 of Set 6 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=arlit
# Processing Record 29 of Set 6 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yaan
# Processing Record 30 of Set 6 | villa florida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=villa%20florida
# Processing Record 31 of Set 6 | rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=rabo%20de%20peixe
# Processing Record 32 of Set 6 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tiarei
# Processing Record 33 of Set 6 | punta umbria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=punta%20umbria
# Processing Record 34 of Set 6 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=anadyr
# Processing Record 35 of Set 6 | seymchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=seymchan
# Processing Record 36 of Set 6 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=evensk
# Processing Record 37 of Set 6 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=flin%20flon
# Processing Record 38 of Set 6 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=namibe
# Processing Record 39 of Set 6 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=champerico
# Processing Record 40 of Set 6 | muisne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=muisne
# Processing Record 41 of Set 6 | villanueva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=villanueva
# Processing Record 42 of Set 6 | doha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=doha
# Processing Record 43 of Set 6 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=airai
# Processing Record 44 of Set 6 | necocli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=necocli
# Processing Record 45 of Set 6 | dibaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=dibaya
# City not found. Skipping...
# Processing Record 46 of Set 6 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=makakilo%20city
# Processing Record 47 of Set 6 | ust-kulom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ust-kulom
# Processing Record 48 of Set 6 | platteville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=platteville
# Processing Record 49 of Set 6 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=umzimvubu
# City not found. Skipping...
# Processing Record 0 of Set 7 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=quatre%20cocos
# Processing Record 1 of Set 7 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=taltal
# Processing Record 2 of Set 7 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hualmay
# Processing Record 3 of Set 7 | kamogawa
# ...
# Processing Record 0 of Set 11 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=muros
# Processing Record 1 of Set 11 | aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=aksu
# Processing Record 2 of Set 11 | manitouwadge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=manitouwadge
# Processing Record 3 of Set 11 | pavilosta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=pavilosta
# Processing Record 4 of Set 11 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=la%20ronge
# Processing Record 5 of Set 11 | fernandez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=fernandez
# Processing Record 6 of Set 11 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yenagoa
# Processing Record 7 of Set 11 | tabulbah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tabulbah
# City not found. Skipping...
# Processing Record 8 of Set 11 | voyvozh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=voyvozh
# Processing Record 9 of Set 11 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ponta%20delgada
# Processing Record 10 of Set 11 | surab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=surab
# Processing Record 11 of Set 11 | boca do acre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=boca%20do%20acre
# Processing Record 12 of Set 11 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=okhotsk
# Processing Record 13 of Set 11 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=udachnyy
# Processing Record 14 of Set 11 | jawhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=jawhar
# Processing Record 15 of Set 11 | soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=soyo
# Processing Record 16 of Set 11 | kampot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kampot
# Processing Record 17 of Set 11 | gondanglegi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=gondanglegi
# Processing Record 18 of Set 11 | kyle of lochalsh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kyle%20of%20lochalsh
# City not found. Skipping...
# Processing Record 19 of Set 11 | sopot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sopot
# Processing Record 20 of Set 11 | luwuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=luwuk
# Processing Record 21 of Set 11 | kolpashevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kolpashevo
# Processing Record 22 of Set 11 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=leh
# Processing Record 23 of Set 11 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 11 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=samusu
# City not found. Skipping...
# Processing Record 25 of Set 11 | rawannawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 11 | kohtla-jarve
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kohtla-jarve
# Processing Record 27 of Set 11 | conde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=conde
# Processing Record 28 of Set 11 | high level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=high%20level
# Processing Record 29 of Set 11 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=grindavik
# Processing Record 30 of Set 11 | port said
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=port%20said
# Processing Record 31 of Set 11 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=moron
# Processing Record 32 of Set 11 | kondinskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kondinskoye
# Processing Record 33 of Set 11 | ginda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ginda
# Processing Record 34 of Set 11 | port augusta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=port%20augusta
# Processing Record 35 of Set 11 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sechura
# Processing Record 36 of Set 11 | herat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=herat
# Processing Record 37 of Set 11 | monte alegre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=monte%20alegre
# Processing Record 38 of Set 11 | christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=christchurch
# Processing Record 39 of Set 11 | carahue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=carahue
# Processing Record 40 of Set 11 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=olinda
# Processing Record 41 of Set 11 | bemidji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bemidji
# Processing Record 42 of Set 11 | wahran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=wahran
# City not found. Skipping...
# Processing Record 43 of Set 11 | campbellsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=campbellsville
# Processing Record 44 of Set 11 | yangambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=yangambi
# Processing Record 45 of Set 11 | nueva esperanza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=nueva%20esperanza
# Processing Record 46 of Set 11 | drayton valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=drayton%20valley
# Processing Record 47 of Set 11 | amberley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=amberley
# Processing Record 48 of Set 11 | rovaniemi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=rovaniemi
# Processing Record 49 of Set 11 | tukrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tukrah
# City not found. Skipping...
# Processing Record 0 of Set 12 | san andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=san%20andres
# Processing Record 1 of Set 12 | chunoyar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=chunoyar
# Processing Record 2 of Set 12 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=cidreira
# Processing Record 3 of Set 12 | melhus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=melhus
# Processing Record 4 of Set 12 | oranjestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=oranjestad
# Processing Record 5 of Set 12 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=touros
# Processing Record 6 of Set 12 | lyndon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=lyndon
# Processing Record 7 of Set 12 | chatellerault
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=chatellerault
# Processing Record 8 of Set 12 | villa maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=villa%20maria
# Processing Record 9 of Set 12 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mount%20isa
# Processing Record 10 of Set 12 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=marcona
# City not found. Skipping...
# Processing Record 11 of Set 12 | kigorobya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kigorobya
# Processing Record 12 of Set 12 | shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=shelburne
# Processing Record 13 of Set 12 | garowe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=garowe
# Processing Record 14 of Set 12 | pimentel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=pimentel
# Processing Record 15 of Set 12 | tunduru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tunduru
# City not found. Skipping...
# Processing Record 16 of Set 12 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vardo
# Processing Record 17 of Set 12 | majene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=majene
# Processing Record 18 of Set 12 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=comodoro%20rivadavia
# Processing Record 19 of Set 12 | talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=talara
# Processing Record 20 of Set 12 | kemijarvi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kemijarvi
# City not found. Skipping...
# Processing Record 21 of Set 12 | bouca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=bouca
# Processing Record 22 of Set 12 | moree
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=moree
# Processing Record 23 of Set 12 | coos bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=coos%20bay
# Processing Record 24 of Set 12 | riohacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=riohacha
# Processing Record 25 of Set 12 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sao%20filipe
# Processing Record 26 of Set 12 | kalemie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kalemie
# Processing Record 27 of Set 12 | ippy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ippy
# Processing Record 28 of Set 12 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 12 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=fukue
# Processing Record 30 of Set 12 | juuru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=juuru
# Processing Record 31 of Set 12 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=hirara
# Processing Record 32 of Set 12 | utiroa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=utiroa
# City not found. Skipping...
# Processing Record 33 of Set 12 | kirkland lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kirkland%20lake
# Processing Record 34 of Set 12 | caucaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=caucaia
# Processing Record 35 of Set 12 | jutai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=jutai
# Processing Record 36 of Set 12 | si sa ket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=si%20sa%20ket
# Processing Record 37 of Set 12 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kirakira
# Processing Record 38 of Set 12 | mizan teferi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=mizan%20teferi
# Processing Record 39 of Set 12 | susanville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=susanville
# Processing Record 40 of Set 12 | jablah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=jablah
# Processing Record 41 of Set 12 | sungairaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=sungairaya
# Processing Record 42 of Set 12 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 12 | uthal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=uthal
# Processing Record 44 of Set 12 | ostersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=ostersund
# Processing Record 45 of Set 12 | custoias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=custoias
# Processing Record 46 of Set 12 | kapuskasing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=kapuskasing
# Processing Record 47 of Set 12 | marysville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=marysville
# Processing Record 48 of Set 12 | gillette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=gillette
# Processing Record 49 of Set 12 | chanika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ec81b973b4b92a260f455e88cc103bef&q=chanika
# -----------------------------
# Data Retrieval Complete
# -----------------------------
